# %%
import pandas as pd

# %%
data = pd.read_csv("departures.csv")
deps_df=data
deps_df.head()
# Out:
#      data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0  05/01/2006  2006      5       12016     GUM        5      13162    MAJ
# 1  05/01/2003  2003      5       10299     ANC        1      13856    OKO
# 2  03/01/2007  2007      3       10721     BOS       13      12651    KEF
# 3  12/01/2004  2004     12       11259     DAL       74      16271    YYZ
# 4  05/01/2009  2009      5       13303     MIA       33      11075    CMW
#
#    fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 0     844      20177     PFQ             1  Departures          0       10
# 1     736      20007      5Y             1  Departures          0       15
# 2     439      20402      GL             1  Departures          0        1
# 3     936      20201     AMQ             1  Departures          0        1
# 4     219      21323      5L             0  Departures          0       20
#
#    Total
# 0     10
# 1     15
# 2      1
# 3      1
# 4     20

# %%
data2 = pd.read_csv("passengers.csv")
pass_df=data2
pass_df.head()
# Out:
#      data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0  05/01/2014  2014      5       14492     RDU       36      11032    CUN
# 1  06/01/2007  2007      6       13204     MCO       33      16085    YHZ
# 2  12/01/2005  2005     12       11433     DTW       43      10411    AUA
# 3  04/01/2003  2003      4       13487     MSP       63      16304    ZIH
# 4  12/01/2005  2005     12       12016     GUM        5      11138    CRK
#
#    fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 0     148      19534      AM             0  Passengers          0      315
# 1     951      20364      C6             0  Passengers          0      683
# 2     277      20344      RD             1  Passengers          0     1010
# 3     148      20204      MG             1  Passengers          0      508
# 4     766      20312      TZ             1  Passengers          0       76
#
#    Total
# 0    315
# 1    683
# 2   1010
# 3    508
# 4     76

# %%
deps_df.count()
# Out:
# data_dte        930808
# Year            930808
# Month           930808
# usg_apt_id      930808
# usg_apt         930808
# usg_wac         930808
# fg_apt_id       930808
# fg_apt          930808
# fg_wac          930808
# airlineid       930808
# carrier         927753
# carriergroup    930808
# type            930808
# Scheduled       930808
# Charter         930808
# Total           930808
# dtype: int64

# %%
deps_df.dtypes
# Out:
# data_dte        object
# Year             int64
# Month            int64
# usg_apt_id       int64
# usg_apt         object
# usg_wac          int64
# fg_apt_id        int64
# fg_apt          object
# fg_wac           int64
# airlineid        int64
# carrier         object
# carriergroup     int64
# type            object
# Scheduled        int64
# Charter          int64
# Total            int64
# dtype: object

# %%
deps_df.nunique()
# Out:
# data_dte         363
# Year              31
# Month             12
# usg_apt_id      1015
# usg_apt         1022
# usg_wac           54
# fg_apt_id       1666
# fg_apt          1669
# fg_wac           229
# airlineid        705
# carrier          734
# carriergroup       2
# type               1
# Scheduled        883
# Charter          255
# Total            886
# dtype: int64

# %%
deps_df.isnull().sum()
# Out:
# data_dte           0
# Year               0
# Month              0
# usg_apt_id         0
# usg_apt            0
# usg_wac            0
# fg_apt_id          0
# fg_apt             0
# fg_wac             0
# airlineid          0
# carrier         3055
# carriergroup       0
# type               0
# Scheduled          0
# Charter            0
# Total              0
# dtype: int64

# %%
deps_df['Year'].max()
# Out:
# 2020

# %%
deps_df['Year'].min()
# Out:
# 1990

# %%
deps_df['usg_apt'].value_counts()
# Out:
# MIA    133820
# JFK     78824
# LAX     57492
# ORD     43853
# EWR     36708
#         ...
# VA5         1
# LKP         1
# OLF         1
# GA7         1
# OWD         1
# Name: usg_apt, Length: 1022, dtype: int64

# %%
deps_df["Total"]
# Out:
# 0           10
# 1           15
# 2            1
# 3            1
# 4           20
#           ...
# 930803    1422
# 930804    1439
# 930805    1441
# 930806    1461
# 930807    2019
# Name: Total, Length: 930808, dtype: int64

# %%
airports = df.groupby('usg_apt')
airports.sum()
# Out:
#             Year  Month  usg_apt_id  usg_wac  fg_apt_id  fg_wac  airlineid  \
# usg_apt
# 1B1         4030     19       20020       44      32542    1872      42874
# 3TX         2020      2       16880       74      16217     941      21437
# A31        16014     14       80352        8     107581    5717     159702
# ABE       718879   2456     3628330     8234    5541413  285133    7264274
# ABI       319239    996     1611624    11766    2181818   52585    3188128
# ...          ...    ...         ...      ...        ...     ...        ...
# YNG        34039    109      274261      748     243865    6060     344629
# YUM        74340    235      600066     2997     539532   17114     759849
# ZXU        12099     52       98118       90      80501    3166     128611
# ZXX         3993     14       32712      186      23920    1034      40084
# ZZZ      1368312   4427    67999320      680    9865355  460404   13947047
#
#          carriergroup  Scheduled  Charter  Total
# usg_apt
# 1B1                 0          0        4      4
# 3TX                 0          0        1      1
# A31                 8        150        0    150
# ABE               212      10695      405  11100
# ABI               157        156        9    165
# ...               ...        ...      ...    ...
# YNG                14          2       47     49
# YUM                24          3      202    205
# ZXU                 2          0        7      7
# ZXX                 2          0        4      4
# ZZZ               680        301     1874   2175
#
# [1022 rows x 11 columns]

# %%
airports['Total'].hist()
# Out:
# usg_apt
# 1B1    AxesSubplot(0.125,0.125;0.775x0.755)
# 3TX    AxesSubplot(0.125,0.125;0.775x0.755)
# A31    AxesSubplot(0.125,0.125;0.775x0.755)
# ABE    AxesSubplot(0.125,0.125;0.775x0.755)
# ABI    AxesSubplot(0.125,0.125;0.775x0.755)
#                        ...
# YNG    AxesSubplot(0.125,0.125;0.775x0.755)
# YUM    AxesSubplot(0.125,0.125;0.775x0.755)
# ZXU    AxesSubplot(0.125,0.125;0.775x0.755)
# ZXX    AxesSubplot(0.125,0.125;0.775x0.755)
# ZZZ    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Total, Length: 1022, dtype: object
